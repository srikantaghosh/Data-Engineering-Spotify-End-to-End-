# %%
# !pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager =  SpotifyClientCredentials(client_id = "a66e7f5e5eb54fcbbb24df0691cdedfa", client_secret="7b813faaf4c24220adc6874f080be86e" )

# %%
sp =  spotipy.Spotify(client_credentials_manager =client_credentials_manager)

# %%
playlist_link ="https://open.spotify.com/playlist/2DCBk0AdKhUxb2ANXckhMO"

# %%
playlist_uri = playlist_link.split("/")[-1]
playlist_uri
# Out:
# '2DCBk0AdKhUxb2ANXckhMO'

# %%
## Using playlist_tracks method, pulling the json playlist

# %%
## get the first album informatiom
data['items'][0]
# Out:
# {'added_at': '2023-06-23T11:46:43Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/er2h73wa2xyezloy6u9iwsjzh'},
#   'href': 'https://api.spotify.com/v1/users/er2h73wa2xyezloy6u9iwsjzh',
#   'id': 'er2h73wa2xyezloy6u9iwsjzh',
#   'type': 'user',
#   'uri': 'spotify:user:er2h73wa2xyezloy6u9iwsjzh'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#      'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#      'id': '0XeEobZplHxzM9QzFQWLiR',
#      'name': 'Eslabon Armado',
#      'type': 'artist',
#      'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
# ...

# %%
## Lets see the volume of data
len(data['items'])
# Out:
# 50

# %%
## pull the same attributes
print(data['items'][0]['track']['album']['id'])
print(data['items'][0]['track']['album']['name'])
print(data['items'][0]['track']['album']['release_date'])
print(data['items'][0]['track']['album']['total_tracks'])
print(data['items'][0]['track']['album']['external_urls']['spotify'])
# Out:
# 5aDEezKnOqyQo0qvTFhpkM
# DESVELADO
# 2023-04-28
# 16
# https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM

# %%
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['release_date']
data['items'][0]['track']['album']['total_tracks']
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    release_date = row['track']['album']['release_date']
    total_tracks = row['track']['album']['total_tracks']
    album_urls = row['track']['album']['external_urls']['spotify']
    
    album_elements = {'album_id':album_id,
                      'album_name':album_name,
                      'release_date': release_date,
                      'total_tracks': total_tracks,
                      'urls':album_urls
                     }
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'album_name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16,
#   'urls': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#  {'album_id': '5dKPhEYBhP8j85HcxQfaw6',
#   'album_name': 'Peso Pluma: Bzrp Music Sessions, Vol. 55',
#   'release_date': '2023-06-01',
#   'total_tracks': 1,
#   'urls': 'https://open.spotify.com/album/5dKPhEYBhP8j85HcxQfaw6'},
#  {'album_id': '5gCcb5fsSb6w5K8SyJrgtB',
#   'album_name': 'WHERE SHE GOES',
#   'release_date': '2023-05-18',
#   'total_tracks': 1,
#   'urls': 'https://open.spotify.com/album/5gCcb5fsSb6w5K8SyJrgtB'},
#  {'album_id': '6N4eyhCAqaGoT3lcEpzBmf',
#   'album_name': 'Rauw Alejandro: Bzrp Music Sessions, Vol. 56',
#   'release_date': '2023-06-21',
#   'total_tracks': 1,
#   'urls': 'https://open.spotify.com/album/6N4eyhCAqaGoT3lcEpzBmf'},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'album_name': 'La Bebe (Remix)',
#   'release_date': '2023-03-17',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0XeEobZplHxzM9QzFQWLiR'},
#   'href': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR',
#   'id': '0XeEobZplHxzM9QzFQWLiR',
#   'name': 'Eslabon Armado',
#   'type': 'artist',
#   'uri': 'spotify:artist:0XeEobZplHxzM9QzFQWLiR'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/12GqGscKJx3aE4t07u7eVZ'},
#   'href': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ',
#   'id': '12GqGscKJx3aE4t07u7eVZ',
#   'name': 'Peso Pluma',
#   'type': 'artist',
#   'uri': 'spotify:artist:12GqGscKJx3aE4t07u7eVZ'}]

# %%
artist_list = []
for  raw in data['items']:
        for key, value in raw.items():
            if key == "track":
                for artist in value["artists"]:
                    artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                    
                    artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'artist_name': 'Bizarrap',
#   'external_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '716NhGYqD1jl2wI1Qkgq36',
#   'artist_name': 'Bizarrap',
#   'external_url': 'https://api.spotify.com/v1/artists/716NhGYqD1jl2wI1Qkgq36'},
#  {'artist_id': '1mcTU81TzQhprhouKaTkpq',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
import pandas as pd
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id                                    album_name  \
# 0  5aDEezKnOqyQo0qvTFhpkM                                     DESVELADO
# 1  5dKPhEYBhP8j85HcxQfaw6      Peso Pluma: Bzrp Music Sessions, Vol. 55
# 2  5gCcb5fsSb6w5K8SyJrgtB                                WHERE SHE GOES
# 3  6N4eyhCAqaGoT3lcEpzBmf  Rauw Alejandro: Bzrp Music Sessions, Vol. 56
# 4  6aBVGuOUEuX18rHxyDWbti                               La Bebe (Remix)
#
#   release_date  total_tracks  \
# 0   2023-04-28            16
# 1   2023-06-01             1
# 2   2023-05-18             1
# 3   2023-06-21             1
# 4   2023-03-17             2
#
#                                                 urls
# 0  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 1  https://open.spotify.com/album/5dKPhEYBhP8j85H...
# 2  https://open.spotify.com/album/5gCcb5fsSb6w5K8...
# 3  https://open.spotify.com/album/6N4eyhCAqaGoT3l...
# 4  https://open.spotify.com/album/6aBVGuOUEuX18rH...

# %%
album_df = album_df.drop_duplicates(subset = ['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 1  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 2  716NhGYqD1jl2wI1Qkgq36        Bizarrap
# 4  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 6  1mcTU81TzQhprhouKaTkpq  Rauw Alejandro
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 1  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 2  https://api.spotify.com/v1/artists/716NhGYqD1j...
# 4  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 6  https://api.spotify.com/v1/artists/1mcTU81TzQh...

# %%
song_df = pd.DataFrame.from_dict(song_list)

song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  3qQbCzHBycnDpGskqOWY0E                               Ella Baila Sola
# 1  5AqiaZwhmC6dIbgWrD5SzV      Peso Pluma: Bzrp Music Sessions, Vol. 55
# 2  7ro0hRteUMfnOioTFI5TG1                                WHERE SHE GOES
# 3  2NFadq6pUeiVEihLvUlOSr  Rauw Alejandro: Bzrp Music Sessions, Vol. 56
# 4  2UW7JaomAMuX9pZrjVpHAU                               La Bebe - Remix
#
#    duration_ms                                                url  popularity  \
# 0       165671  https://open.spotify.com/track/3qQbCzHBycnDpGs...          93
# 1       188361  https://open.spotify.com/track/5AqiaZwhmC6dIbg...          97
# 2       231704  https://open.spotify.com/track/7ro0hRteUMfnOio...          99
# 3       191254  https://open.spotify.com/track/2NFadq6pUeiVEih...          85
# 4       234352  https://open.spotify.com/track/2UW7JaomAMuX9pZ...         100
#
# ...

# %% [markdown]
# album_df
# song_df
# artist_df
#
#
# ## Transformation

# %%
album_df.head(5)
# Out:
#                  album_id                                    album_name  \
# 0  5aDEezKnOqyQo0qvTFhpkM                                     DESVELADO
# 1  5dKPhEYBhP8j85HcxQfaw6      Peso Pluma: Bzrp Music Sessions, Vol. 55
# 2  5gCcb5fsSb6w5K8SyJrgtB                                WHERE SHE GOES
# 3  6N4eyhCAqaGoT3lcEpzBmf  Rauw Alejandro: Bzrp Music Sessions, Vol. 56
# 4  6aBVGuOUEuX18rHxyDWbti                               La Bebe (Remix)
#
#   release_date  total_tracks  \
# 0   2023-04-28            16
# 1   2023-06-01             1
# 2   2023-05-18             1
# 3   2023-06-21             1
# 4   2023-03-17             2
#
#                                                 urls
# 0  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 1  https://open.spotify.com/album/5dKPhEYBhP8j85H...
# 2  https://open.spotify.com/album/5gCcb5fsSb6w5K8...
# 3  https://open.spotify.com/album/6N4eyhCAqaGoT3l...
# 4  https://open.spotify.com/album/6aBVGuOUEuX18rH...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_name    50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   urls          50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.3+ KB

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   album_name    50 non-null     object
#  2   release_date  50 non-null     datetime64[ns]
#  3   total_tracks  50 non-null     int64
#  4   urls          50 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.3+ KB

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  3qQbCzHBycnDpGskqOWY0E                               Ella Baila Sola
# 1  5AqiaZwhmC6dIbgWrD5SzV      Peso Pluma: Bzrp Music Sessions, Vol. 55
# 2  7ro0hRteUMfnOioTFI5TG1                                WHERE SHE GOES
# 3  2NFadq6pUeiVEihLvUlOSr  Rauw Alejandro: Bzrp Music Sessions, Vol. 56
# 4  2UW7JaomAMuX9pZrjVpHAU                               La Bebe - Remix
#
#    duration_ms                                                url  popularity  \
# 0       165671  https://open.spotify.com/track/3qQbCzHBycnDpGs...          93
# 1       188361  https://open.spotify.com/track/5AqiaZwhmC6dIbg...          97
# 2       231704  https://open.spotify.com/track/7ro0hRteUMfnOio...          99
# 3       191254  https://open.spotify.com/track/2NFadq6pUeiVEih...          85
# 4       234352  https://open.spotify.com/track/2UW7JaomAMuX9pZ...         100
#
# ...

# %%
  song_df['song_added'] = pd.to_datetime(song_df['song_added'])
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.2+ KB
